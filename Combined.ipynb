# %%
import pandas as pd
import os
import glob

# %%
cwd = os.path.abspath('')

# %%
file_list = os.listdir(cwd)
file_list
# Out:
# ['Untitled Folder',
#  '202006-citibike-tripdata.csv',
#  '202010-citibike-tripdata.csv',
#  '.DS_Store',
#  'Untitled.ipynb',
#  '202008-citibike-tripdata.csv',
#  '202011-citibike-tripdata.csv',
#  '202007-citibike-tripdata.csv',
#  '.ipynb_checkpoints',
#  '202009-citibike-tripdata.csv']

# %%
csv_files = glob.glob('*.{}'.format('csv'))
csv_files
# Out:
# ['202006-citibike-tripdata.csv',
#  '202010-citibike-tripdata.csv',
#  '202008-citibike-tripdata.csv',
#  '202011-citibike-tripdata.csv',
#  '202007-citibike-tripdata.csv',
#  '202009-citibike-tripdata.csv']

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
            df_temp = pd.read_csv(file)
            df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
# /var/folders/t2/mwglxl8d7c79zvdzfp786mnw0000gn/T/ipykernel_1684/3254637134.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_append = df_append.append(df_temp, ignore_index=True)
#           tripduration                 starttime                  stoptime  \
# 0                 1062  2020-06-01 00:00:03.3720  2020-06-01 00:17:46.2080
# 1                 3810  2020-06-01 00:00:03.5530  2020-06-01 01:03:33.9360
# 2                 1017  2020-06-01 00:00:09.6140  2020-06-01 00:17:06.8330
# 3                  226  2020-06-01 00:00:12.1780  2020-06-01 00:03:58.8640
# 4                 1437  2020-06-01 00:00:21.2550  2020-06-01 00:24:18.9650
# ...                ...                       ...                       ...
# 12791388          1818  2020-09-30 23:59:48.8460  2020-10-01 00:30:07.7810
# 12791389          1553  2020-09-30 23:59:53.7240  2020-10-01 00:25:47.1760
# 12791390           626  2020-09-30 23:59:54.6670  2020-10-01 00:10:21.6050
# 12791391           325  2020-09-30 23:59:56.2120  2020-10-01 00:05:21.3060
# 12791392           128  2020-09-30 23:59:57.8350  2020-10-01 00:02:06.0920
#
#           start station id           start station name  \
# 0                     3419          Douglass St & 4 Ave
# 1                      366     Clinton Ave & Myrtle Ave
# 2                      389          Broadway & Berry St
# 3                     3255              8 Ave & W 31 St
# 4                      367      E 53 St & Lexington Ave
# ...                    ...                          ...
# 12791388               284        Greenwich Ave & 8 Ave
# 12791389               390  Duffield St & Willoughby St
# 12791390              3901   Stanhope St & Fairview Ave
# 12791391              3148              E 84 St & 1 Ave
# 12791392               439               E 4 St & 2 Ave
#
#           start station latitude  start station longitude  end station id  \
# 0                      40.679279               -73.981540            3419
# 1                      40.693261               -73.968896             336
# 2                      40.710446               -73.965251            3562
# 3                      40.750585               -73.994685             505
# 4                      40.758281               -73.970694             497
# ...                          ...                      ...             ...
# 12791388               40.739017               -74.002638            3836
# 12791389               40.692216               -73.984284            3799
# 12791390               40.709980               -73.911160            3083
# 12791391               40.775655               -73.950686            3338
# 12791392               40.726281               -73.989780             312
#
#                      end station name  end station latitude  \
# 0                 Douglass St & 4 Ave             40.679279
# 1         Sullivan St & Washington Sq             40.730477
# 2          Classon Ave & St Marks Ave             40.676520
# 3                     6 Ave & W 33 St             40.749013
# 4                  E 17 St & Broadway             40.737050
# ...                               ...                   ...
# 12791388     Bushwick Ave & Linden St             40.691460
# 12791389              6 Ave & W 34 St             40.749640
# 12791390     Bushwick Ave & Powers St             40.712477
# 12791391              2 Ave & E 99 St             40.786259
# 12791392        Allen St & Stanton St             40.722055
#
#           end station longitude  bikeid    usertype  birth year  gender
# 0                    -73.981540   39852    Customer        1997       2
# 1                    -73.999061   37558  Subscriber        1969       0
# 2                    -73.959608   37512    Customer        1988       2
# 3                    -73.988484   39674    Customer        1969       0
# 4                    -73.990093   21093    Customer        1997       2
# ...                         ...     ...         ...         ...     ...
# 12791388             -73.921460   36220  Subscriber        1993       1
# 12791389             -73.988050   31092  Subscriber        1995       1
# 12791390             -73.941000   47224  Subscriber        1954       2
# 12791391             -73.945526   16759  Subscriber        1995       2
# 12791392             -73.989111   47718  Subscriber        1996       2
#
# [12791393 rows x 15 columns]

# %%
df_append.to_csv('combined_files.csv')
